# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Completed: 22/9

# %% [markdown]
# ## Lab 4.2.2: Feature Selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

wine_csv = 'winequality_merged.csv'

# Load the wine dataset from csv
wine = pd.read_csv(wine_csv)

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  red_wine
# 0      9.4         1
# 1      9.8         1
# 2      9.8         1
# 3      9.8         1
# 4      9.4         1

# %%
X.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# red_wine                   0.486740          0.653036    -0.187397
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# red_wine                   -0.348821   0.512678            -0.471644
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# red_wine                         -0.700357  0.390645  0.329129   0.487218
#
#                        alcohol  red_wine
# fixed acidity        -0.095452  0.486740
# volatile acidity     -0.037640  0.653036
# citric acid          -0.010493 -0.187397
# residual sugar       -0.359415 -0.348821
# chlorides            -0.256916  0.512678
# free sulfur dioxide  -0.179838 -0.471644
# total sulfur dioxide -0.265740 -0.700357
# density              -0.686745  0.390645
# pH                    0.121248  0.329129
# sulphates            -0.003029  0.487218
# alcohol               1.000000 -0.032970
# red_wine             -0.032970  1.000000

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
## Create training and testing subsets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression()
# get the number of cases in the test data
n = X_test.shape[0]

r2_list = []
adjusted_r2_list = []

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

        # fit the model with the Training data
        fit = model.fit(X_train[included + [new_column]], y_train)
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_train[included + [new_column]], y_train)
        
        # number of predictors in this model
        k = len(included) + 1
        # calculate the adjusted R^2
        adjusted_r2 = 1 - ( ( (1 - r2) * (n - 1) ) / (n - k - 1) )
        
        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for
    
    r2_list.append(best['r2'])
    adjusted_r2_list.append(best['a_r2'])

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        print('*'*50)
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = citric acid, chlorides, residual sugar, sulphates, total sulfur dioxide, fixed acidity, density, red_wine, alcohol, free sulfur dioxide, volatile acidity, pH
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.006; Best = 0.000
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.007; Adjusted R^2 = 0.006
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.044; Best = 0.006
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.044; Adjusted R^2 = 0.044
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = 0.001; Best = 0.044
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = 0.001; Best = 0.044
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.001; Best = 0.044
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.006; Best = 0.044
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.099; Best = 0.044
# (Step) - New Best!   : Feature = density; R^2 = 0.099; Adjusted R^2 = 0.099
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.014; Best = 0.099
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.206; Best = 0.099
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.207; Adjusted R^2 = 0.206
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.003; Best = 0.206
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.070; Best = 0.206
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = -0.000; Best = 0.206
# Added feature alcohol with R^2 = 0.207 and adjusted R^2 = 0.206
#
# (Step) Excluded = citric acid, chlorides, residual sugar, sulphates, total sulfur dioxide, fixed acidity, density, red_wine, free sulfur dioxide, volatile acidity, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.213; Best = 0.206
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.214; Adjusted R^2 = 0.213
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.214; Best = 0.213
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.215; Adjusted R^2 = 0.214
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.221; Best = 0.214
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.222; Adjusted R^2 = 0.221
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.207; Best = 0.221
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.213; Best = 0.221
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.207; Best = 0.221
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.205; Best = 0.221
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.216; Best = 0.221
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.228; Best = 0.221
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.229; Adjusted R^2 = 0.228
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.267; Best = 0.228
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.268; Adjusted R^2 = 0.267
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.206; Best = 0.267
# Added feature volatile acidity with R^2 = 0.268 and adjusted R^2 = 0.267
#
# (Step) Excluded = citric acid, chlorides, residual sugar, sulphates, total sulfur dioxide, fixed acidity, density, red_wine, free sulfur dioxide, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.266; Best = 0.267
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.266; Best = 0.267
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.271; Best = 0.267
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.273; Adjusted R^2 = 0.271
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.276; Best = 0.271
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.278; Adjusted R^2 = 0.276
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.267; Best = 0.276
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.266; Best = 0.276
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.273; Best = 0.276
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.272; Best = 0.276
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.270; Best = 0.276
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.267; Best = 0.276
# Added feature sulphates with R^2 = 0.278 and adjusted R^2 = 0.276
#
# (Step) Excluded = citric acid, chlorides, residual sugar, total sulfur dioxide, fixed acidity, density, red_wine, free sulfur dioxide, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.276; Best = 0.276
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.276; Best = 0.276
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.278; Adjusted R^2 = 0.276
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar
# (Step) - Adjusted R^2: This = 0.284; Best = 0.276
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.286; Adjusted R^2 = 0.284
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.275; Best = 0.284
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.275; Best = 0.284
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, density
# (Step) - Adjusted R^2: This = 0.279; Best = 0.284
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, red_wine
# (Step) - Adjusted R^2: This = 0.276; Best = 0.284
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.281; Best = 0.284
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, pH
# (Step) - Adjusted R^2: This = 0.276; Best = 0.284
# Added feature residual sugar with R^2 = 0.286 and adjusted R^2 = 0.284
#
# (Step) Excluded = citric acid, chlorides, total sulfur dioxide, fixed acidity, density, red_wine, free sulfur dioxide, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.284; Best = 0.284
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.287; Adjusted R^2 = 0.284
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.283; Best = 0.284
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.285; Best = 0.284
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.288; Adjusted R^2 = 0.285
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.283; Best = 0.285
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, density
# (Step) - Adjusted R^2: This = 0.283; Best = 0.285
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.287; Best = 0.285
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.290; Adjusted R^2 = 0.287
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.285; Best = 0.287
# Added feature red_wine with R^2 = 0.290 and adjusted R^2 = 0.287
#
# (Step) Excluded = citric acid, chlorides, total sulfur dioxide, fixed acidity, density, free sulfur dioxide, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.288; Best = 0.287
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.291; Adjusted R^2 = 0.288
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.288; Best = 0.288
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.291; Adjusted R^2 = 0.288
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.287; Best = 0.288
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.287; Best = 0.288
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.291; Best = 0.288
# (Step) - New Best!   : Feature = density; R^2 = 0.294; Adjusted R^2 = 0.291
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.292; Best = 0.291
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.295; Adjusted R^2 = 0.292
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.287; Best = 0.292
# Added feature free sulfur dioxide with R^2 = 0.295 and adjusted R^2 = 0.292
#
# (Step) Excluded = citric acid, chlorides, total sulfur dioxide, fixed acidity, density, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.292; Best = 0.292
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.296; Adjusted R^2 = 0.292
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.292; Best = 0.292
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.296; Adjusted R^2 = 0.292
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.294; Best = 0.292
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.298; Adjusted R^2 = 0.294
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.291; Best = 0.294
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) - New Best!   : Feature = density; R^2 = 0.298; Adjusted R^2 = 0.294
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.292; Best = 0.294
# Added feature density with R^2 = 0.298 and adjusted R^2 = 0.294
#
# (Step) Excluded = citric acid, chlorides, total sulfur dioxide, fixed acidity, pH
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, citric acid
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, chlorides
# (Step) - Adjusted R^2: This = 0.295; Best = 0.294
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.299; Adjusted R^2 = 0.295
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.296; Best = 0.295
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.301; Adjusted R^2 = 0.296
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.294; Best = 0.296
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, pH
# (Step) - Adjusted R^2: This = 0.295; Best = 0.296
# Added feature total sulfur dioxide with R^2 = 0.301 and adjusted R^2 = 0.296
#
# (Step) Excluded = citric acid, pH, fixed acidity, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.296; Best = 0.296
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.297; Best = 0.296
# (Step) - New Best!   : Feature = pH; R^2 = 0.302; Adjusted R^2 = 0.297
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.296; Best = 0.297
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.297; Best = 0.297
# Added feature pH   with R^2 = 0.302 and adjusted R^2 = 0.297
#
# (Step) Excluded = citric acid, fixed acidity, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH, citric acid
# (Step) - Adjusted R^2: This = 0.296; Best = 0.297
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.299; Best = 0.297
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.305; Adjusted R^2 = 0.299
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH, chlorides
# (Step) - Adjusted R^2: This = 0.297; Best = 0.299
# Added feature fixed acidity with R^2 = 0.305 and adjusted R^2 = 0.299
#
# (Step) Excluded = citric acid, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.299; Best = 0.299
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH, fixed acidity, chlorides
# (Step) - Adjusted R^2: This = 0.299; Best = 0.299
# **************************************************
#
# Resulting features:
# alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density, total sulfur dioxide, pH, fixed acidity

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
